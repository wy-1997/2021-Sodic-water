# %%
import pandas as pd
import numpy as np
import os
import lightgbm
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error 
from sklearn import preprocessing, metrics


from borax.calendars.lunardate import LunarDate

# %% [markdown]
# 考虑使用china_day进行周期性趋势检验

# %% [markdown]
# 新增年度周期

# %%
"""
时间变量特征
"""
def create_features(dataframe):
    dataframe['date'] = pd.to_datetime(dataframe['date'])
    dataframe['month'] = dataframe.China_date.dt.month  #农历月
    dataframe['day_of_month'] = dataframe.China_date.dt.day #农历日
    dataframe['day_of_year'] = dataframe.China_date.dt.dayofyear #农历的哪一天
    dataframe['week_of_year'] = dataframe.date.dt.weekofyear
    dataframe['day_of_week'] = dataframe.date.dt.dayofweek + 1
    dataframe['year'] = dataframe.date.dt.year
    dataframe['is_wknd'] = dataframe.date.dt.weekday // 4
    dataframe['is_month_start'] = dataframe.date.dt.is_month_start.astype(int)
    dataframe['is_month_end'] = dataframe.date.dt.is_month_end.astype(int)
    dataframe['quarter'] = dataframe.date.dt.quarter
    dataframe['week_block_num'] = [int(x) for x in np.floor((dataframe.date - pd.to_datetime('2017-12-31')).dt.days / 7) + 1]
    dataframe['quarter_block_num'] = (dataframe['year'] - 2018) * 4 + dataframe['quarter']
    dataframe['week_of_month'] = dataframe['week_of_year'].values // 4.35
    #dataframe['WKD_TYP_CD']=dataframe['WKD_TYP_CD'].map({'WN':0,'SN': 1, 'NH': 1, 'SS': 1, 'WS': 0})
    #新增星期几时间变量
    dataframe['is_Mon'] = np.where(dataframe['day_of_week'] == 1, 1, 0)                                                                                       
    dataframe['is_Tue'] = np.where(dataframe['day_of_week'] == 2, 1, 0)                                                                                         
    dataframe['is_Wed'] = np.where(dataframe['day_of_week'] == 3, 1, 0)                                                                                         
    dataframe['is_Thu'] = np.where(dataframe['day_of_week'] == 4, 1, 0)                                                                                         
    dataframe['is_Fri'] = np.where(dataframe['day_of_week'] == 5, 1, 0)                                                                                         
    dataframe['is_Sat'] = np.where(dataframe['day_of_week'] == 6, 1, 0)                                                                                         
    dataframe['is_Sun'] = np.where(dataframe['day_of_week'] == 7, 1, 0)
    dataframe['abs_month']=dataframe['day_of_month'].apply(lambda x: abs(x-16)+1)
    #dataframe.drop(['date','post_id'],axis=1,inplace=True)
    return dataframe

# %%
"""
围绕目标的分组特征、趋势性、周期性
"""
def group_features(df):
    #每年每月分组统计特征
    df['year_month_A_mean']=df.groupby(['month'])['B'].transform('mean').values
    df['year_month_A_std']=df.groupby(['month'])['B'].transform('std').values
    df['year_month_A_skew']=df.groupby(['month'])['B'].transform('skew').values
    df['year_month_A_max']=df.groupby(['month'])['B'].transform('max').values
    df['year_month_A_min']=df.groupby(['month'])['B'].transform('min').values
    df['year_month_A_median']=df.groupby(['month'])['B'].transform('median').values
    #数据倾斜分析
    df['A_minus_year_month_A_mean']=df['B']-df['year_month_A_mean']
    df['cv'] = df['year_month_A_std'] / df['year_month_A_mean']
    df['magic_feature1_1'] = df['year_month_A_median'] - df['year_month_A_mean']
    df['magic_feature1_2'] = df['magic_feature1_1'].map(abs)
    df['magic_feature2'] = df['year_month_A_median'] / df['year_month_A_mean']
    #中位数特征分析(用于分析目标与每月中位数的趋势结果)
    df['A_minus_year_month_A_median']=df['B']-df['year_month_A_median']
    df['A_ratio_year_month_A_median']=df['B'] / df['year_month_A_median']
    df['A_minus_year_month_A_mean']=df['B']-df['year_month_A_mean']
    df['A_ratio_year_month_A_mean']=df['B'] / df['year_month_A_mean']    
    #对称性分析
    df['abs_month']=df['day_of_month'].apply(lambda x: abs(x-16)+1)
    #时间序列分析中的差分结果分析
    df['year_month_A_median_diff'] = df['year_month_A_median'].diff(1)
    df['year_month_A_mean_diff'] = df['year_month_A_mean'].diff(1)
    return df


def lag_rolling_diff(df,col):
    for i in [1,2,3,5,7,15,30]:
        df['lag_'+col+'_'+str(i)] = df[col].transform(lambda x: x.shift(i))

    for j in [2,3,5,7,15,30]:    
        df['rolling_mean_'+col+'_'+str(j)] = df[col].transform(lambda x: x.shift(7).rolling(j).mean())
        
        df['new_lag_'+'rolling_mean_'+col+'_'+str(j)] = df['rolling_mean_'+col+'_'+str(j)].shift(1)

        df['rolling_std_'+col+'_'+str(j)]  = df[col].transform(lambda x: x.shift(7).rolling(j).std())
        
        df['new_lag_'+'rolling_std_'+col+'_'+str(j)] = df['rolling_std_'+col+'_'+str(j)].shift(1)        
    
    for k in [1,2,3]:
        df['diff_'+col+'_'+str(k)] = df[col].transform(lambda x: x.diff(k))
        

    
    return df

# %%
def yang2nong(date):
    
    year = int(date[:4])
    month = int(date[4:6])
    day = int(date[6:8])
    
    nong =  LunarDate.from_solar_date(year, month, day)
    
    res = nong.__format__('%y-%m-%d')
    return res

# %%
##lgb模型的构建
def lgb_cv(train_x, train_y, test_x):
    predictors = list(train_x.columns)
    train_x = train_x.values
    test_x = test_x.values


    folds = 10
    seed = 2021
    kf = KFold(n_splits=folds, shuffle=True, random_state=seed)
    train = np.zeros((train_x.shape[0]))
    test = np.zeros((test_x.shape[0]))
    test_pre = np.zeros((folds, test_x.shape[0]))
    test_pre_all = np.zeros((folds, test_x.shape[0]))
    cv_scores = []
    tpr_scores = []
    cv_rounds = []

    for i, (train_index, test_index) in enumerate(kf.split(train_x, train_y)):
        tr_x = train_x[train_index]
        tr_y = train_y[train_index]
        te_x = train_x[test_index]
        te_y = train_y[test_index]
        train_matrix = lightgbm.Dataset(tr_x, label=tr_y)
        test_matrix = lightgbm.Dataset(te_x, label=te_y)
        params = {
                'boosting_type': 'gbdt',
                'objective': 'regression',
                'metrics':'mean_squared_error',
                'num_leaves': 2 ** 5-1,
                'feature_fraction': 0.8,
                'bagging_fraction': 0.8,
                'learning_rate': 0.1,
                #'lambda_l1': 0.01,                                                                                                                    
                #'lambda_l2': 0.01,
                'seed': 2021,


                'nthread': 20,
                'verbose': -1,


        }
        num_round = 10000
        early_stopping_rounds = 200    

        if test_matrix:
            model = lightgbm.train(params, train_matrix, num_round, valid_sets=test_matrix, verbose_eval=200,
                                #feval=tpr_eval_score,
                                early_stopping_rounds=early_stopping_rounds
                                )
            
            importance_list=[ x[0] for x in list(sorted(zip(predictors, model.feature_importance("gain")),
                        key=lambda x: x[1],reverse=True))]
            
            features_imp = pd.DataFrame(list(sorted(zip(predictors, model.feature_importance("gain")))),columns=['features','gain'])
            features_imp.to_csv('features_imp_B.csv',index=False)
            #print(A)

            
            pre = model.predict(te_x, num_iteration=model.best_iteration)#
            pred = model.predict(test_x, num_iteration=model.best_iteration)#

            train[test_index] = pre
            test_pre[i, :] = pred
            cv_scores.append(mean_squared_error (te_y, pre))
            cv_rounds.append(model.best_iteration)
            test_pre_all[i, :] = pred
           
        print("cv_score is:", cv_scores)
    use_mean=True
    if use_mean:
        test[:] = test_pre.mean(axis=0)
    else:
        pass
    print('-'*50)


    val1 = model.predict(df[select_frts].iloc[1005:1035])
    val1_rmse = np.sqrt(metrics.mean_squared_error(df['B'].iloc[1005:1035],
                                                    val1))
    print(f'loacl valid scores is {val1_rmse}')    
    
    print("val_mean:" , np.mean(cv_scores))
    print("val_std:", np.std(cv_scores))
    return train, test, test_pre_all, np.mean(cv_scores),importance_list

# %%
df.columns
# Out:
# Index(['date', 'A', 'B', 'WKD_TYP_CD', 'date1', 'China_date', 'month',
#        'day_of_month', 'day_of_year', 'week_of_year', 'day_of_week', 'year',
#        'is_wknd', 'is_month_start', 'is_month_end', 'quarter',
#        'week_block_num', 'quarter_block_num', 'week_of_month', 'is_Mon',
#        'is_Tue', 'is_Wed', 'is_Thu', 'is_Fri', 'is_Sat', 'is_Sun', 'abs_month',
#        'year_month_A_mean', 'year_month_A_std', 'year_month_A_skew',
#        'year_month_A_max', 'year_month_A_min', 'year_month_A_median',
#        'A_minus_year_month_A_mean', 'cv', 'magic_feature1_1',
#        'magic_feature1_2', 'magic_feature2', 'A_minus_year_month_A_median',
#        'A_ratio_year_month_A_median', 'A_ratio_year_month_A_mean',
#        'year_month_A_median_diff', 'year_month_A_mean_diff', 'lag_B_1',
#        'lag_B_2', 'lag_B_3', 'lag_B_5', 'lag_B_7', 'lag_B_15', 'lag_B_30',
#        'rolling_mean_B_2', 'new_lag_rolling_mean_B_2', 'rolling_std_B_2',
#        'new_lag_rolling_std_B_2', 'rolling_mean_B_3',
#        'new_lag_rolling_mean_B_3', 'rolling_std_B_3',
#        'new_lag_rolling_std_B_3', 'rolling_mean_B_5',
#        'new_lag_rolling_mean_B_5', 'rolling_std_B_5',
#        'new_lag_rolling_std_B_5', 'rolling_mean_B_7',
#        'new_lag_rolling_mean_B_7', 'rolling_std_B_7',
#        'new_lag_rolling_std_B_7', 'rolling_mean_B_15',
#        'new_lag_rolling_mean_B_15', 'rolling_std_B_15',
#        'new_lag_rolling_std_B_15', 'rolling_mean_B_30',
#        'new_lag_rolling_mean_B_30', 'rolling_std_B_30',
#        'new_lag_rolling_std_B_30', 'diff_B_1', 'diff_B_2', 'diff_B_3'],
#       dtype='object')

# %%
# %time
if __name__=="__main__":
    #数据读取与wkd表连接
    train_df=pd.read_csv('../data/train.csv')
    wkd = pd.DataFrame({"date":['2018/01/01','2018/02/15','2018/02/16','2018/02/17','2018/02/18','2018/02/19',
'2018/02/20','2018/02/21','2018/04/05','2018/04/06',
'2018/04/30','2018/05/01','2018/06/18','2018/09/24','2018/10/01','2018/10/02','2018/10/03',
'2018/10/04','2018/10/05','2018/12/31','2019/01/01',
'2019/02/04','2019/02/05','2019/02/06','2019/02/07','2019/02/08','2019/04/05','2019/05/01',
'2019/05/02','2019/05/03','2019/06/07','2019/09/13','2019/10/01',
'2019/10/02','2019/10/03','2019/10/04','2019/10/07','2020/01/01',
'2020/01/24','2020/01/25','2020/01/26','2020/01/27','2020/01/28','2020/01/29','2020/01/30','2020/01/31','2020/04/04',
'2020/04/06','2020/05/01','2020/05/04','2020/05/05','2020/06/25','2020/06/26','2020/10/01','2020/10/02','2020/10/03',
'2020/10/04','2020/10/05','2020/10/06','2020/10/07','2020/10/08','2021/01/01','2021/02/11',
'2021/02/12','2021/02/13','2021/02/14','2021/02/15','2021/02/16','2021/02/17','2021/04/04','2021/04/05',]
})
wkd['wkd']=1
wkd
    
    train_df.columns=['date','A','B']
    train_df.date=pd.to_datetime(train_df.date)
    test_day=pd.read_csv('../data/test.csv')#按天计算
    wkd=pd.read_csv('../data/wkd_v1.csv')
    wkd=wkd.rename(columns={'ORIG_DT':'date'})
    wkd.date=pd.to_datetime(wkd.date)
    train_df=train_df.merge(wkd,on='date',how='left')
    test_day.columns = ['date','A','B']
    test_day.date = pd.to_datetime(test_day.date)
    test_day = test_day.merge(wkd,on='date',how='left')

    df=pd.concat([train_df,test_day],axis=0)
    df['WKD_TYP_CD']=df['WKD_TYP_CD'].map({'WN':0,'SN': 1, 'NH': 1, 'SS': 1, 'WS': 0})
    #进行农历转换
    df['date1'] = df.date.dt.strftime('%Y%m%d')
    df['China_date']=df['date1'].apply(lambda x: yang2nong(x))
    #农历2月不同与公历2月，
    #因此采用前向填充方式以构建pandas时间戳，难题在与20年存在的闰四月现象    
    df.replace(['2018-2-29','2018-2-30','2019-2-29',
            '2020-2-29','2020-2-30'],np.nan,inplace=True)
    
    df['China_date']=df['China_date'].fillna(method='ffill')
    df['China_date'] = pd.to_datetime(df['China_date'])

    start_day = 1035    
    
    print('*'*50)
    #选择相应的features
    select_frts=[ 'WKD_TYP_CD', 'month', 'day_of_month', 'day_of_year',
       'week_of_year', 'day_of_week', 'year', 'is_wknd', 'is_month_start',
       'is_month_end', 'quarter', 'week_block_num', 'quarter_block_num',
       'week_of_month', 'is_Mon', 'is_Tue', 'is_Wed', 'is_Thu', 'is_Fri',
       'is_Sat', 'is_Sun', 'abs_month', 'lag_B_1', 'lag_B_2', 'lag_B_3', 'lag_B_5',
       'lag_B_7','lag_B_15', 'lag_B_30','rolling_mean_B_2', 'new_lag_rolling_mean_B_2', 'rolling_std_B_2',
       'new_lag_rolling_std_B_2', 'rolling_mean_B_3',
       'new_lag_rolling_mean_B_3', 'rolling_std_B_3',
       'new_lag_rolling_std_B_3', 'rolling_mean_B_5',
       'new_lag_rolling_mean_B_5', 'rolling_std_B_5',
       'new_lag_rolling_std_B_5', 'rolling_mean_B_7',
       'new_lag_rolling_mean_B_7', 'rolling_std_B_7',
       'new_lag_rolling_std_B_7', 'rolling_mean_B_15',
       'new_lag_rolling_mean_B_15', 'rolling_std_B_15',
       'new_lag_rolling_std_B_15', 'rolling_mean_B_30',
       'new_lag_rolling_mean_B_30', 'rolling_std_B_30',
       'new_lag_rolling_std_B_30',
       ]
    
    #df.iloc[1035:1036]['A']=df.iloc[1034:1035]['A']
    for j in range(90): 
        df=create_features(df)
        df = group_features(df)
        df = lag_rolling_diff(df,'B')
        print(f'开始第{j+1}天的预测')
        train_day_df_B = df[:start_day+j]  #此时需要动态构建训练集与测试集
        test_day_df_B = df[start_day+j:start_day+j+1]  #start_day + for 循环


        train_df=train_day_df_B.reset_index(drop=True)#训练集A
        #试试从19年6月开始预测
        train_df=train_df[train_df['date']>='2019-06-01'].reset_index(drop=True)
        test_df=test_day_df_B[0:1]#测试集A
        train_x = train_df[select_frts].copy()
        train_y = train_df['B']
        test_x = test_df[select_frts].copy()
        print(train_x.shape,train_y.shape,test_x.shape)
        lgb_train, lgb_test, sb, cv_scores, importance_list = lgb_cv(train_x, train_y, test_x)
        lgb_test_B=[item if item>0 else 0 for item in lgb_test]
        pre_B=np.array(lgb_test_B)
        print(f'第{j+1}天的预测值为{pre_B}')

        df[start_day+j:start_day+j+1]['B'] = lgb_test_B
# Out:
# Wall time: 0 ns
# **************************************************
# 开始第1天的预测
# (519, 53) (519,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.08985e+08
# Early stopping, best iteration is:
# [132]	valid_0's l2: 1.06826e+08
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# cv_score is: [106826407.71132246]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.75553e+08
# Early stopping, best iteration is:
# [81]	valid_0's l2: 1.70206e+08
# cv_score is: [106826407.71132246, 170206346.41389054]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.49167e+07
# Early stopping, best iteration is:
# [37]	valid_0's l2: 8.64493e+07
# cv_score is: [106826407.71132246, 170206346.41389054, 86449331.66581543]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.07536e+07
# Early stopping, best iteration is:
# [50]	valid_0's l2: 6.6171e+07
# cv_score is: [106826407.71132246, 170206346.41389054, 86449331.66581543, 66171042.62906777]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.1053e+07
# Early stopping, best iteration is:
# [69]	valid_0's l2: 6.37113e+07
# cv_score is: [106826407.71132246, 170206346.41389054, 86449331.66581543, 66171042.62906777, 63711261.98541567]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.08656e+07
# Early stopping, best iteration is:
# [47]	valid_0's l2: 8.85664e+07
# cv_score is: [106826407.71132246, 170206346.41389054, 86449331.66581543, 66171042.62906777, 63711261.98541567, 88566359.61964558]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.03361e+08
# Early stopping, best iteration is:
# [188]	valid_0's l2: 1.03287e+08
# cv_score is: [106826407.71132246, 170206346.41389054, 86449331.66581543, 66171042.62906777, 63711261.98541567, 88566359.61964558, 103286559.79230587]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 2.58938e+08
# [400]	valid_0's l2: 2.55278e+08
# [600]	valid_0's l2: 2.54807e+08
# [800]	valid_0's l2: 2.54238e+08
# [1000]	valid_0's l2: 2.5401e+08
# [1200]	valid_0's l2: 2.53911e+08
# [1400]	valid_0's l2: 2.53863e+08
# [1600]	valid_0's l2: 2.5384e+08
# [1800]	valid_0's l2: 2.53828e+08
# [2000]	valid_0's l2: 2.53821e+08
# [2200]	valid_0's l2: 2.53815e+08
# [2400]	valid_0's l2: 2.53811e+08
# [2600]	valid_0's l2: 2.5381e+08
# [2800]	valid_0's l2: 2.53809e+08
# [3000]	valid_0's l2: 2.53809e+08
# [3200]	valid_0's l2: 2.53808e+08
# [3400]	valid_0's l2: 2.53808e+08
# [3600]	valid_0's l2: 2.53808e+08
# [3800]	valid_0's l2: 2.53808e+08
# [4000]	valid_0's l2: 2.53808e+08
# [4200]	valid_0's l2: 2.53808e+08
# [4400]	valid_0's l2: 2.53808e+08
# [4600]	valid_0's l2: 2.53808e+08
# [4800]	valid_0's l2: 2.53808e+08
# [5000]	valid_0's l2: 2.53808e+08
# [5200]	valid_0's l2: 2.53808e+08
# [5400]	valid_0's l2: 2.53808e+08
# [5600]	valid_0's l2: 2.53808e+08
# [5800]	valid_0's l2: 2.53808e+08
# [6000]	valid_0's l2: 2.53808e+08
# [6200]	valid_0's l2: 2.53808e+08
# [6400]	valid_0's l2: 2.53808e+08
# [6600]	valid_0's l2: 2.53808e+08
# [6800]	valid_0's l2: 2.53808e+08
# [7000]	valid_0's l2: 2.53808e+08
# [7200]	valid_0's l2: 2.53808e+08
# [7400]	valid_0's l2: 2.53808e+08
# [7600]	valid_0's l2: 2.53808e+08
# [7800]	valid_0's l2: 2.53808e+08
# [8000]	valid_0's l2: 2.53808e+08
# [8200]	valid_0's l2: 2.53808e+08
# Early stopping, best iteration is:
# [8082]	valid_0's l2: 2.53808e+08
# cv_score is: [106826407.71132246, 170206346.41389054, 86449331.66581543, 66171042.62906777, 63711261.98541567, 88566359.61964558, 103286559.79230587, 253808282.0492636]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.1416e+07
# Early stopping, best iteration is:
# [141]	valid_0's l2: 5.03896e+07
# cv_score is: [106826407.71132246, 170206346.41389054, 86449331.66581543, 66171042.62906777, 63711261.98541567, 88566359.61964558, 103286559.79230587, 253808282.0492636, 50389609.10689286]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.79113e+07
# Early stopping, best iteration is:
# [38]	valid_0's l2: 7.43397e+07
# cv_score is: [106826407.71132246, 170206346.41389054, 86449331.66581543, 66171042.62906777, 63711261.98541567, 88566359.61964558, 103286559.79230587, 253808282.0492636, 50389609.10689286, 74339664.1969538]
# --------------------------------------------------
# loacl valid scores is 4795.8228732489215
# val_mean: 106375486.51705734
# val_std: 58422696.84308371
# 第1天的预测值为[237347.67595194]
# 开始第2天的预测
# (520, 53) (520,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.44661e+08
# Early stopping, best iteration is:
# [98]	valid_0's l2: 1.41536e+08
# cv_score is: [141535675.76021326]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.2571e+07
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# Early stopping, best iteration is:
# [161]	valid_0's l2: 6.21772e+07
# cv_score is: [141535675.76021326, 62177151.11101529]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.5535e+08
# Early stopping, best iteration is:
# [44]	valid_0's l2: 1.49432e+08
# cv_score is: [141535675.76021326, 62177151.11101529, 149431980.6862314]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.60843e+07
# Early stopping, best iteration is:
# [38]	valid_0's l2: 6.73045e+07
# cv_score is: [141535675.76021326, 62177151.11101529, 149431980.6862314, 67304530.08199276]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 4.86723e+07
# Early stopping, best iteration is:
# [81]	valid_0's l2: 4.666e+07
# cv_score is: [141535675.76021326, 62177151.11101529, 149431980.6862314, 67304530.08199276, 46659959.76885427]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.77854e+07
# Early stopping, best iteration is:
# [34]	valid_0's l2: 6.85336e+07
# cv_score is: [141535675.76021326, 62177151.11101529, 149431980.6862314, 67304530.08199276, 46659959.76885427, 68533570.05652629]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.00436e+08
# Early stopping, best iteration is:
# [33]	valid_0's l2: 8.38166e+07
# cv_score is: [141535675.76021326, 62177151.11101529, 149431980.6862314, 67304530.08199276, 46659959.76885427, 68533570.05652629, 83816634.7723151]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 2
# cv_score is: [211067570.0446845, 51973631.00181071, 65249786.31777675, 78705106.02369489, 46675981.86558097, 95389019.7560033, 88347112.33922292, 239063184.42975333]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.31604e+07
# Early stopping, best iteration is:
# [125]	valid_0's l2: 7.29338e+07
# cv_score is: [211067570.0446845, 51973631.00181071, 65249786.31777675, 78705106.02369489, 46675981.86558097, 95389019.7560033, 88347112.33922292, 239063184.42975333, 72933799.08633947]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.65879e+07
# Early stopping, best iteration is:
# [42]	valid_0's l2: 6.50769e+07
# cv_score is: [211067570.0446845, 51973631.00181071, 65249786.31777675, 78705106.02369489, 46675981.86558097, 95389019.7560033, 88347112.33922292, 239063184.42975333, 72933799.08633947, 65076855.74351527]
# --------------------------------------------------
# loacl valid scores is 3267.1248415239374
# val_mean: 101448204.66083822
# val_std: 63697637.68606587
# 第3天的预测值为[239925.27606629]
# 开始第4天的预测
# (522, 53) (522,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 2.3579e+08
# Early stopping, best iteration is:
# [181]	valid_0's l2: 2.34966e+08
# cv_score is: [234966133.63014886]
# Training until validation scores don't improve for 200 rounds
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# [200]	valid_0's l2: 7.01461e+07
# Early stopping, best iteration is:
# [81]	valid_0's l2: 6.32687e+07
# cv_score is: [234966133.63014886, 63268650.03822821]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.22263e+07
# Early stopping, best iteration is:
# [180]	valid_0's l2: 5.17441e+07
# cv_score is: [234966133.63014886, 63268650.03822821, 51744072.46733448]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 8.92363e+07
# Early stopping, best iteration is:
# [67]	valid_0's l2: 8.51396e+07
# cv_score is: [234966133.63014886, 63268650.03822821, 51744072.46733448, 85139646.31125349]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.0099e+07
# Early stopping, best iteration is:
# [53]	valid_0's l2: 4.45e+07
# cv_score is: [234966133.63014886, 63268650.03822821, 51744072.46733448, 85139646.31125349, 44499975.94921108]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.12039e+07
# Early stopping, best iteration is:
# [38]	valid_0's l2: 7.83055e+07
# cv_score is: [234966133.63014886, 63268650.03822821, 51744072.46733448, 85139646.31125349, 44499975.94921108, 78305456.02584772]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 8.72699e+07
# Early stopping, best iteration is:
# [82]	valid_0's l2: 8.45777e+07
# cv_score is: [234966133.63014886, 63268650.03822821, 51744072.46733448, 85139646.31125349, 44499975.94921108, 78305456.02584772, 84577737.85333504]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 2.39534e+08
# [400]	valid_0's l2: 2.34613e+08
# [600]	valid_0's l2: 2.33919e+08
# [800]	valid_0's l2: 2.33555e+08
# [1000]	valid_0's l2: 2.33368e+08
# [1200]	valid_0's l2: 2.33284e+08
# [1400]	valid_0's l2: 2.33255e+08
# [1600]	valid_0's l2: 2.33255e+08
# Early stopping, best iteration is:
# [1513]	valid_0's l2: 2.33251e+08
# cv_score is: [234966133.63014886, 63268650.03822821, 51744072.46733448, 85139646.31125349, 44499975.94921108, 78305456.02584772, 84577737.85333504, 233250537.5119087]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.84703e+07
# Early stopping, best iteration is:
# [103]	valid_0's l2: 6.76304e+07
# cv_score is: [234966133.63014886, 63268650.03822821, 51744072.46733448, 85139646.31125349, 44499975.94921108, 78305456.02584772, 84577737.85333504, 233250537.5119087, 67630384.7767865]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.40798e+07
# Early stopping, best iteration is:
# [41]	valid_0's l2: 5.79187e+07
# cv_score is: [234966133.63014886, 63268650.03822821, 51744072.46733448, 85139646.31125349, 44499975.94921108, 78305456.02584772, 84577737.85333504, 233250537.5119087, 67630384.7767865, 57918738.25265051]
# --------------------------------------------------
# loacl valid scores is 3614.878375474548
# val_mean: 100130133.28167045
# val_std: 68174355.15568396
# 第4天的预测值为[235169.95856462]
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# 开始第5天的预测
# (523, 53) (523,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.28199e+08
# Early stopping, best iteration is:
# [28]	valid_0's l2: 1.20257e+08
# cv_score is: [120257029.98254791]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2:
# cv_score is: [106539189.26101838, 159279337.6225193, 63212366.32202572, 60562913.21096231, 77722995.08523837, 88614937.71700913, 86437256.06587397, 250361563.16447636]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.73459e+07
# [400]	valid_0's l2: 5.56603e+07
# [600]	valid_0's l2: 5.48864e+07
# [800]	valid_0's l2: 5.47575e+07
# [1000]	valid_0's l2: 5.48303e+07
# Early stopping, best iteration is:
# [881]	valid_0's l2: 5.4734e+07
# cv_score is: [106539189.26101838, 159279337.6225193, 63212366.32202572, 60562913.21096231, 77722995.08523837, 88614937.71700913, 86437256.06587397, 250361563.16447636, 54734031.38038524]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.68306e+07
# Early stopping, best iteration is:
# [50]	valid_0's l2: 6.56624e+07
# cv_score is: [106539189.26101838, 159279337.6225193, 63212366.32202572, 60562913.21096231, 77722995.08523837, 88614937.71700913, 86437256.06587397, 250361563.16447636, 54734031.38038524, 65662355.04684149]
# --------------------------------------------------
# loacl valid scores is 3008.3172627790104
# val_mean: 101312694.48763503
# val_std: 57527990.6397371
# 第6天的预测值为[236065.43635711]
# 开始第7天的预测
# (525, 53) (525,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.67195e+08
# Early stopping, best iteration is:
# [144]	valid_0's l2: 1.66227e+08
# cv_score is:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
#  [166226639.3158179]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 4.51288e+07
# Early stopping, best iteration is:
# [42]	valid_0's l2: 4.02646e+07
# cv_score is: [166226639.3158179, 40264630.18395143]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 8.15771e+07
# Early stopping, best iteration is:
# [61]	valid_0's l2: 7.83926e+07
# cv_score is: [166226639.3158179, 40264630.18395143, 78392557.28399055]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.07338e+07
# Early stopping, best iteration is:
# [46]	valid_0's l2: 5.76671e+07
# cv_score is: [166226639.3158179, 40264630.18395143, 78392557.28399055, 57667128.93862324]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.77548e+07
# [400]	valid_0's l2: 9.60422e+07
# [600]	valid_0's l2: 9.53794e+07
# [800]	valid_0's l2: 9.52762e+07
# [1000]	valid_0's l2: 9.50924e+07
# [1200]	valid_0's l2: 9.51205e+07
# Early stopping, best iteration is:
# [1022]	valid_0's l2: 9.50711e+07
# cv_score is: [166226639.3158179, 40264630.18395143, 78392557.28399055, 57667128.93862324, 95071085.54532441]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.15081e+08
# Early stopping, best iteration is:
# [93]	valid_0's l2: 1.09845e+08
# cv_score is: [166226639.3158179, 40264630.18395143, 78392557.28399055, 57667128.93862324, 95071085.54532441, 109844721.48849656]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.00785e+08
# Early stopping, best iteration is:
# [33]	valid_0's l2: 8.61946e+07
# cv_score is: [166226639.3158179, 40264630.18395143, 78392557.28399055, 57667128.93862324, 95071085.54532441, 109844721.48849656, 86194607.23973411]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 2.63898e+08
# Early stopping, best iteration is:
# [189]	valid_0's l2: 2.62708e+08
# cv_score is: [166226639.3158179, 40264630.18395143, 78392557.28399055, 57667128.93862324, 95071085.54532441, 109844721.48849656, 86194607.23973411, 262708236.66194278]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.31862e+07
# [400]	valid_0's l2: 5.30391e+07
# [600]	valid_0's l2: 5.30537e+07
# Early stopping, best iteration is:
# [436]	valid_0's l2: 5.29304e+07
# cv_score is: [166226639.3158179, 40264630.18395143, 78392557.28399055, 57667128.93862324, 95071085.54532441, 109844721.48849656, 86194607.23973411, 262708236.66194278, 52930412.93703136]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.15512e+07
# Early stopping, best iteration is:
# [38]	valid_0's l2: 6.303e+07
# cv_score is: [166226639.3158179, 40264630.18395143, 78392557.28399055, 57667128.93862324, 95071085.54532441, 109844721.48849656, 86194607.23973411, 262708236.66194278, 52930412.93703136, 63029950.94074996]
# --------------------------------------------------
# loacl valid scores is 3633.37806055343
# val_mean: 101232997.05356625
# val_std: 63691549.9397876
# 第7天的预测值为[234795.52180874]
# 开始第8天的预测
# (526, 53) (526,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.03421e+07
# Early stopping, best iteration is:
# [80]	valid_0's l2: 4.7196e+07
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# cv_score is: [47196004.03189122]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.18028e+08
# Early stopping, best iteration is:
# [115]	valid_0's l2: 1.14374e+08
# cv_score is: [47196004.03189122, 114373909.29166752]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.13723e+08
# Early stopping, best iteration is:
# [26]	valid_0's l2: 1.11059e+08
# cv_score is: [47196004.03189122, 114373909.29166752, 111058750.71624212]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.16055e+08
# Early stopping, best iteration is:
# [69]	valid_0's l2: 1.12637e+08
# cv_score is: [47196004.03189122, 114373909.29166752, 111058750.71624212, 112637110.41302936]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 8.8135e+07
# Early stopping, best iteration is:
# [138]	valid_0's l2: 8.50322e+07
# cv_score is: [47196004.03189122, 114373909.29166752, 111058750.71624212, 112637110.41302936, 85032156.30062838]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.21307e+07
# Early stopping, best iteration is:
# [71]	valid_0's l2: 6.9829e+07
# cv_score is: [47196004.03189122, 114373909.29166752, 111058750.71624212, 112637110.41302936, 85032156.30062838, 69829046.4123]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.13303e+08
# Early stopping, best iteration is:
# [29]	valid_0's l2: 1.00313e+08
# cv_score is: [47196004.03189122, 114373909.29166752, 111058750.71624212, 112637110.41302936, 85032156.30062838, 69829046.4123, 100312647.95144701]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 2.01475e+08
# [400]	valid_0's l2: 2.02604e+08
# Early stopping, best iteration is:
# [249]	valid_0's l2: 2.00546e+08
# cv_score is: [47196004.03189122, 114373909.29166752, 111058750.71624212, 112637110.41302936, 85032156.30062838, 69829046.4123, 100312647.95144701, 200545650.55281323]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.42648e+08
# Early stopping, best iteration is:
# [125]	valid_0's l2: 1.41e+08
# cv_score is: [47196004.03189122, 114373909.29166752, 111058750.71624212, 112637110.41302936, 85032156.30062838, 69829046.4123, 100312647.95144701, 200545650.55281323, 141000165.4129929]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.95536e+07
# Early stopping, best iteration is:
# [48]	valid_0's l2: 7.20553e+07
# cv_score is: [47196004.03189122, 114373909.29166752, 111058750.71624212, 112637110.41302936, 85032156.30062838, 69829046.4123, 100312647.95144701, 200545650.55281323, 141000165.4129929, 72055298.67487265]
# --------------------------------------------------
# loacl valid scores is 3658.967121346987
# val_mean: 105404073.97578843
# val_std: 40854120.85143379
# 第8天的预测值为[234469.04158718]
# 开始第9天的预测
# (527, 53) (527,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.71431e+07
# Early stopping, best iteration is:
# [181]	valid_0's l2: 7.66209e+07
# cv_score is: [76620943.15928778]
# Training until validation scores don't improve for 200 rounds
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# [200]	valid_0's l2: 1.06032e+08
# [400]	valid_0's l2: 1.05125e+08
# Early stopping, best iteration is:
# [235]	valid_0's l2: 1.04611e+08
# cv_score is: [76620943.15928778, 104611240.23395823]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.73868e+07
# Early stopping, best iteration is:
# [76]	valid_0's l2: 7.52414e+07
# cv_score is: [76620943.15928778, 104611240.23395823, 75241357.27964187]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.46513e+08
# Early stopping, best iteration is:
# [89]	valid_0's l2: 1.42737e+08
# cv_score is: [76620943.15928778, 104611240.23395823, 75241357.27964187, 142737478.752525]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.56275e+07
# Early stopping, best iteration is:
# [121]	valid_0's l2: 9.48742e+07
# cv_score is: [76620943.15928778, 104611240.23395823, 75241357.27964187, 142737478.752525, 94874248.65996821]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.59958e+07
# Early stopping, best iteration is:
# [35]	valid_0's l2: 5.67393e+07
# cv_score is: [76620943.15928778, 104611240.23395823, 75241357.27964187, 142737478.752525, 94874248.65996821, 56739325.9358461]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.13687e+07
# Early stopping, best iteration is:
# [31]	valid_0's l2: 8.74201e+07
# cv_score is: [76620943.15928778, 104611240.23395823, 75241357.27964187, 142737478.752525, 94874248.65996821, 56739325.9358461, 87420129.90248387]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.75769e+08
# [400]	valid_0's l2: 1.74899e+08
# Early stopping, best iteration is:
# [343]	valid_0's l2: 1.74548e+08
# cv_score is: [76620943.15928778, 104611240.23395823, 75241357.27964187, 142737478.752525, 94874248.65996821, 56739325.9358461, 87420129.90248387, 174547709.35643223]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.45812e+08
# [400]	valid_0's l2: 1.43906e+08
# Early stopping, best iteration is:
# [377]	valid_0's l2: 1.43753e+08
# cv_score is: [76620943.15928778, 104611240.23395823, 75241357.27964187, 142737478.752525, 94874248.65996821, 56739325.9358461, 87420129.90248387, 174547709.35643223, 143752515.78994447]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.3669e+07
# Early stopping, best iteration is:
# [94]	valid_0's l2: 7.19978e+07
# cv_score is: [76620943.15928778, 104611240.23395823, 75241357.27964187, 142737478.752525, 94874248.65996821, 56739325.9358461, 87420129.90248387, 174547709.35643223, 143752515.78994447, 71997828.06123441]
# --------------------------------------------------
# loacl valid scores is 2007.727579925238
# val_mean: 102854277.71313222
# val_std: 36383560.741879515
# 第9天的预测值为[240029.41777711]
# 开始第10天的预测
# (528, 53) (528,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.16446e+07
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# Early stopping, best iteration is:
# [171]	valid_0's l2: 9.04738e+07
# cv_score is: [90473795.89224762]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 4.79572e+07
# Early stopping, best iteration is:
# [99]	valid_0's l2: 4.52707e+07
# cv_score is: [90473795.89224762, 45270722.31195008]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.39811e+08
# Early stopping, best iteration is:
# [97]	valid_0's l2: 1.36372e+08
# cv_score is: [90473795.89224762, 45270722.31195008, 136372061.10059842]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.15796e+07
# Early stopping, best iteration is:
# [80]	valid_0's l2: 4.70556e+07
# cv_score is: [90473795.89224762, 45270722.31195008, 136372061.10059842, 47055625.42149279]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.18561e+08
# Early stopping, best iteration is:
# [32]	valid_0's l2: 1.14788e+08
# cv_score is: [90473795.89224762, 45270722.31195008, 136372061.10059842, 47055625.42149279, 114788023.06731682]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.61434e+07
# Early stopping, best iteration is:
# [34]	valid_0's l2: 8.81801e+07
# cv_score is: [90473795.89224762, 45270722.31195008, 136372061.10059842, 47055625.42149279, 114788023.06731682, 88180101.13102746]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.03841e+08
# Early stopping, best iteration is:
# [42]	valid_0's l2: 9.82622e+07
# cv_score is: [90473795.89224762, 45270722.31195008, 136372061.10059842, 47055625.42149279, 114788023.06731682, 88180101.13102746, 98262216.55300196]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.96563e+08
# [400]	valid_0's l2: 1.98145e+08
# Early stopping, best iteration is:
# [202]	valid_0's l2: 1.96346e+08
# cv_score is: [90473795.89224762, 45270722.31195008, 136372061.10059842, 47055625.42149279, 114788023.06731682, 88180101.13102746, 98262216.55300196, 196346053.14878926]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.3752e+08
# [400]	valid_0's l2: 1.35541e+08
# Early stopping, best iteration is:
# [344]	valid_0's l2: 1.35217e+08
# cv_score is: [90473795.89224762, 45270722.31195008, 136372061.10059842, 47055625.42149279, 114788023.06731682, 88180101.13102746, 98262216.55300196, 196346053.14878926, 135216727.43353087]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.89423e+07
# Early stopping, best iteration is:
# [47]	valid_0's l2: 7.24492e+07
# cv_score is: [90473795.89224762, 45270722.31195008, 136372061.10059842, 47055625.42149279, 114788023.06731682, 88180101.13102746, 98262216.55300196, 196346053.14878926, 135216727.43353087, 72449233.39664787]
# --------------------------------------------------
# loacl valid scores is 3290.408871281444
# val_mean: 102441455.94566032
# val_std: 43354018.353040114
# 第10天的预测值为[244185.87772072]
# 开始第11天的预测
# (529, 53) (529,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# [200]	valid_0's l2: 9.60372e+07
# Early stopping, best iteration is:
# [105]	valid_0's l2: 9.17885e+07
# cv_score is: [91788485.00846979]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.60728e+07
# Early stopping, best iteration is:
# [168]	valid_0's l2: 5.58178e+07
# cv_score is: [91788485.00846979, 55817752.87685604]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.25875e+08
# Early stopping, best iteration is:
# [127]	valid_0's l2: 1.23163e+08
# cv_score is: [91788485.00846979, 55817752.87685604, 123163497.8883534]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.63242e+07
# [400]	valid_0's l2: 5.55957e+07
# [600]	valid_0's l2: 5.48894e+07
# [800]	valid_0's l2: 5.4559e+07
# [1000]	valid_0's l2: 5.44293e+07
# [1200]	valid_0's l2: 5.4393e+07
# [1400]	valid_0's l2: 5.4383e+07
# [1600]	valid_0's l2: 5.43787e+07
# Early stopping, best iteration is:
# [1540]	valid_0's l2: 5.43769e+07
# cv_score is: [91788485.00846979, 55817752.87685604, 123163497.8883534, 54376891.0085744]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.54446e+08
# Early stopping, best iteration is:
# [35]	valid_0's l2: 1.47082e+08
# cv_score is: [91788485.00846979, 55817752.87685604, 123163497.8883534, 54376891.0085744, 147082425.41619718]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.74229e+07
# Early stopping, best iteration is:
# [57]	valid_0's l2: 5.82004e+07
# cv_score is: [91788485.00846979, 55817752.87685604, 123163497.8883534, 54376891.0085744, 147082425.41619718, 58200400.586805545]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.24028e+08
# Early stopping, best iteration is:
# [28]	valid_0's l2: 1.15767e+08
# cv_score is: [91788485.00846979, 55817752.87685604, 123163497.8883534, 54376891.0085744, 147082425.41619718, 58200400.586805545, 115767284.30050735]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.72725e+08
# Early stopping, best iteration is:
# [98]	valid_0's l2: 1.70201e+08
# cv_score is: [91788485.00846979, 55817752.87685604, 123163497.8883534, 54376891.0085744, 147082425.41619718, 58200400.586805545, 115767284.30050735, 170201401.44212136]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.49322e+08
# [400]	valid_0's l2: 1.47313e+08
# [600]	valid_0's l2: 1.46997e+08
# [800]	valid_0's l2: 1.46869e+08
# Early stopping, best iteration is:
# [770]	valid_0's l2: 1.46805e+08
# cv_score is: [91788485.00846979, 55817752.87685604, 123163497.8883534, 54376891.0085744, 147082425.41619718, 58200400.586805545, 115767284.30050735, 170201401.44212136, 146804728.07551885]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.46147e+07
# Early stopping, best iteration is:
# [37]	valid_0's l2: 6.73518e+07
# cv_score is: [91788485.00846979, 55817752.87685604, 123163497.8883534, 54376891.0085744, 147082425.41619718, 58200400.586805545, 115767284.30050735, 170201401.44212136, 146804728.07551885, 67351808.96561264]
# --------------------------------------------------
# loacl valid scores is 3918.5272494458904
# val_mean: 103055467.55690166
# val_std: 41160113.081390426
# 第11天的预测值为[242683.65485744]
# 开始第12天的预测
# (530, 53) (530,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.68026e+07
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# Early stopping, best iteration is:
# [62]	valid_0's l2: 9.27211e+07
# cv_score is: [92721116.83459724]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.08238e+08
# Early stopping, best iteration is:
# [63]	valid_0's l2: 1.04611e+08
# cv_score is: [92721116.83459724, 104610801.37868991]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.31687e+08
# Early stopping, best iteration is:
# [164]	valid_0's l2: 1.30966e+08
# cv_score is: [92721116.83459724, 104610801.37868991, 130965862.83796157]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.43628e+07
# Early stopping, best iteration is:
# [89]	valid_0's l2: 5.27777e+07
# cv_score is: [92721116.83459724, 104610801.37868991, 130965862.83796157, 52777707.09071464]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.04394e+08
# Early stopping, best iteration is:
# [72]	valid_0's l2: 1.01762e+08
# cv_score is: [92721116.83459724, 104610801.37868991, 130965862.83796157, 52777707.09071464, 101761912.60577187]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.58916e+07
# Early stopping, best iteration is:
# [32]	valid_0's l2: 6.13957e+07
# cv_score is: [92721116.83459724, 104610801.37868991, 130965862.83796157, 52777707.09071464, 101761912.60577187, 61395705.415956266]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.16605e+08
# Early stopping, best iteration is:
# [29]	valid_0's l2: 1.05911e+08
# cv_score is: [92721116.83459724, 104610801.37868991, 130965862.83796157, 52777707.09071464, 101761912.60577187, 61395705.415956266, 105911390.33769505]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.65038e+08
# Early stopping, best iteration is:
# [163]	valid_0's l2: 1.64429e+08
# cv_score is: [92721116.83459724, 104610801.37868991, 130965862.83796157, 52777707.09071464, 101761912.60577187, 61395705.415956266, 105911390.33769505, 164428757.863249]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.57703e+08
# Early stopping, best iteration is:
# [96]	valid_0's l2: 1.54944e+08
# cv_score is: [92721116.83459724, 104610801.37868991, 130965862.83796157, 52777707.09071464, 101761912.60577187, 61395705.415956266, 105911390.33769505, 164428757.863249, 154943608.49896008]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 7.45673e+07
# Early stopping, best iteration is:
# [49]	valid_0's l2: 6.84536e+07
# cv_score is: [92721116.83459724, 104610801.37868991, 130965862.83796157, 52777707.09071464, 101761912.60577187, 61395705.415956266, 105911390.33769505, 164428757.863249, 154943608.49896008, 68453595.04173934]
# --------------------------------------------------
# loacl valid scores is 3384.4273018229005
# val_mean: 103797045.79053351
# val_std: 35794240.7708424
# 第12天的预测值为[242638.11399957]
# 开始第13天的预测
# (531, 53) (531,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# [200]	valid_0's l2: 4.73345e+07
# Early stopping, best iteration is:
# [70]	valid_0's l2: 4.60924e+07
# cv_score is: [46092406.393053874]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.31125e+08
# Early stopping, best iteration is:
# [190]	valid_0's l2: 1.30408e+08
# cv_score is: [46092406.393053874, 130408238.3307671]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.28259e+07
# Early stopping, best iteration is:
# [198]	valid_0's l2: 9.27786e+07
# cv_score is: [46092406.393053874, 130408238.3307671, 92778643.18599366]
# ...
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.41367e+08
# [400]	valid_0's l2: 1.41524e+08
# Early stopping, best iteration is:
# [270]	valid_0's l2: 1.40741e+08
# cv_score is: [69987996.91680735, 95011217.3812633, 118644160.62915866, 69322285.53651263, 122002761.8582096, 33234013.52086419, 100055216.4611116, 67955435.60726656, 140741417.0415785]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.87784e+07
# Early stopping, best iteration is:
# [79]	valid_0's l2: 5.67725e+07
# cv_score is: [69987996.91680735, 95011217.3812633, 118644160.62915866, 69322285.53651263, 122002761.8582096, 33234013.52086419, 100055216.4611116, 67955435.60726656, 140741417.0415785, 56772526.24964661]
# --------------------------------------------------
# loacl valid scores is 2368.8562799568367
# val_mean: 87372703.12024191
# val_std: 31807235.1702382
# 第86天的预测值为[201666.15712726]
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# 开始第87天的预测
# (605, 53) (605,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.41263e+07
# Early stopping, best iteration is:
# [40]	valid_0's l2: 5.75172e+07
# cv_score is: [57517170.32379394]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.03665e+08
# Early stopping, best iteration is:
# [38]	valid_0's l2: 9.974e+07
# cv_score is: [57517170.32379394, 99740004.77911521]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.59821e+08
# Early stopping, best iteration is:
# [22]	valid_0's l2: 1.36941e+08
# cv_score is: [57517170.32379394, 99740004.77911521, 136940854.97900242]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.91029e+07
# Early stopping, best iteration is:
# [113]	valid_0's l2: 9.56926e+07
# cv_score is: [57517170.32379394, 99740004.77911521, 136940854.97900242, 95692632.90709634]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.27331e+08
# [400]	valid_0's l2: 1.27152e+08
# Early stopping, best iteration is:
# [247]	valid_0's l2: 1.26609e+08
# cv_score is: [57517170.32379394, 99740004.77911521, 136940854.97900242, 95692632.90709634, 126609422.65506543]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 4.60725e+07
# Early stopping, best iteration is:
# [53]	valid_0's l2: 3.88958e+07
# cv_score is: [57517170.32379394, 99740004.77911521, 136940854.97900242, 95692632.90709634, 126609422.65506543, 38895780.29650279]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.04162e+08
# Early stopping, best iteration is:
# [24]	valid_0's l2: 8.19586e+07
# cv_score is: [57517170.32379394, 99740004.77911521, 136940854.97900242, 95692632.90709634, 126609422.65506543, 38895780.29650279, 81958592.41674124]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 8.92238e+07
# Early stopping, best iteration is:
# [46]	valid_0's l2: 8.40203e+07
# cv_score is: [57517170.32379394, 99740004.77911521, 136940854.97900242, 95692632.90709634, 126609422.65506543, 38895780.29650279, 81958592.41674124, 84020304.9615354]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.44277e+08
# [400]	valid_0's l2: 1.43373e+08
# Early stopping, best iteration is:
# [260]	valid_0's l2: 1.42868e+08
# cv_score is: [57517170.32379394, 99740004.77911521, 136940854.97900242, 95692632.90709634, 126609422.65506543, 38895780.29650279, 81958592.41674124, 84020304.9615354, 142868045.15031353]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.57101e+07
# Early stopping, best iteration is:
# [116]	valid_0's l2: 6.50565e+07
# cv_score is: [57517170.32379394, 99740004.77911521, 136940854.97900242, 95692632.90709634, 126609422.65506543, 38895780.29650279, 81958592.41674124, 84020304.9615354, 142868045.15031353, 65056478.61728067]
# --------------------------------------------------
# loacl valid scores is 2110.247325654497
# val_mean: 92929928.70864469
# val_std: 32816959.90546247
# 第87天的预测值为[206601.57909051]
# 开始第88天的预测
# (606, 53) (606,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# [200]	valid_0's l2: 8.75598e+07
# Early stopping, best iteration is:
# [135]	valid_0's l2: 8.59469e+07
# cv_score is: [85946869.8510895]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.3046e+07
# Early stopping, best iteration is:
# [109]	valid_0's l2: 5.17654e+07
# cv_score is: [85946869.8510895, 51765418.5593386]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.51958e+08
# Early stopping, best iteration is:
# [27]	valid_0's l2: 1.34225e+08
# cv_score is: [85946869.8510895, 51765418.5593386, 134224807.02978718]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.49321e+07
# Early stopping, best iteration is:
# [67]	valid_0's l2: 9.34073e+07
# cv_score is: [85946869.8510895, 51765418.5593386, 134224807.02978718, 93407280.3446862]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.23866e+08
# [400]	valid_0's l2: 1.23861e+08
# Early stopping, best iteration is:
# [287]	valid_0's l2: 1.23434e+08
# cv_score is: [85946869.8510895, 51765418.5593386, 134224807.02978718, 93407280.3446862, 123433834.59055808]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 3.39109e+07
# Early stopping, best iteration is:
# [60]	valid_0's l2: 2.70057e+07
# cv_score is: [85946869.8510895, 51765418.5593386, 134224807.02978718, 93407280.3446862, 123433834.59055808, 27005687.279213645]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 8.92441e+07
# Early stopping, best iteration is:
# [29]	valid_0's l2: 8.02198e+07
# cv_score is: [85946869.8510895, 51765418.5593386, 134224807.02978718, 93407280.3446862, 123433834.59055808, 27005687.279213645, 80219827.84032325]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 8.24874e+07
# Early stopping, best iteration is:
# [37]	valid_0's l2: 7.75897e+07
# cv_score is: [85946869.8510895, 51765418.5593386, 134224807.02978718, 93407280.3446862, 123433834.59055808, 27005687.279213645, 80219827.84032325, 77589653.34862489]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.366e+08
# [400]	valid_0's l2: 1.35039e+08
# Early stopping, best iteration is:
# [283]	valid_0's l2: 1.34753e+08
# cv_score is: [85946869.8510895, 51765418.5593386, 134224807.02978718, 93407280.3446862, 123433834.59055808, 27005687.279213645, 80219827.84032325, 77589653.34862489, 134752525.38300133]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.6145e+07
# Early stopping, best iteration is:
# [143]	valid_0's l2: 5.47354e+07
# cv_score is: [85946869.8510895, 51765418.5593386, 134224807.02978718, 93407280.3446862, 123433834.59055808, 27005687.279213645, 80219827.84032325, 77589653.34862489, 134752525.38300133, 54735441.65840123]
# --------------------------------------------------
# loacl valid scores is 1803.1240746318433
# val_mean: 86308134.58850239
# val_std: 34484208.41661744
# 第88天的预测值为[206789.29607852]
# 开始第89天的预测
# (607, 53) (607,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.8896e+07
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# Early stopping, best iteration is:
# [112]	valid_0's l2: 9.61664e+07
# cv_score is: [96166393.50537269]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.45724e+07
# Early stopping, best iteration is:
# [74]	valid_0's l2: 4.99155e+07
# cv_score is: [96166393.50537269, 49915453.059719265]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.56911e+08
# Early stopping, best iteration is:
# [33]	valid_0's l2: 1.48338e+08
# cv_score is: [96166393.50537269, 49915453.059719265, 148338048.97429603]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.24819e+07
# Early stopping, best iteration is:
# [50]	valid_0's l2: 8.65549e+07
# cv_score is: [96166393.50537269, 49915453.059719265, 148338048.97429603, 86554889.54330118]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.34014e+08
# [400]	valid_0's l2: 1.32138e+08
# [600]	valid_0's l2: 1.32367e+08
# Early stopping, best iteration is:
# [419]	valid_0's l2: 1.31994e+08
# cv_score is: [96166393.50537269, 49915453.059719265, 148338048.97429603, 86554889.54330118, 131994238.9302161]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.00218e+07
# Early stopping, best iteration is:
# [37]	valid_0's l2: 4.4352e+07
# cv_score is: [96166393.50537269, 49915453.059719265, 148338048.97429603, 86554889.54330118, 131994238.9302161, 44351979.629993714]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 9.1233e+07
# Early stopping, best iteration is:
# [25]	valid_0's l2: 8.28002e+07
# cv_score is: [96166393.50537269, 49915453.059719265, 148338048.97429603, 86554889.54330118, 131994238.9302161, 44351979.629993714, 82800247.39976142]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.73526e+07
# Early stopping, best iteration is:
# [59]	valid_0's l2: 6.19204e+07
# cv_score is: [96166393.50537269, 49915453.059719265, 148338048.97429603, 86554889.54330118, 131994238.9302161, 44351979.629993714, 82800247.39976142, 61920361.72965506]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.44612e+08
# [400]	valid_0's l2: 1.44567e+08
# Early stopping, best iteration is:
# [279]	valid_0's l2: 1.43626e+08
# cv_score is: [96166393.50537269, 49915453.059719265, 148338048.97429603, 86554889.54330118, 131994238.9302161, 44351979.629993714, 82800247.39976142, 61920361.72965506, 143626452.3058791]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 5.3918e+07
# Early stopping, best iteration is:
# [188]	valid_0's l2: 5.35518e+07
# cv_score is: [96166393.50537269, 49915453.059719265, 148338048.97429603, 86554889.54330118, 131994238.9302161, 44351979.629993714, 82800247.39976142, 61920361.72965506, 143626452.3058791, 53551764.43134964]
# --------------------------------------------------
# loacl valid scores is 1495.784805177329
# val_mean: 89921982.95095442
# val_std: 37352057.29644175
# 第89天的预测值为[202873.51067517]
# 开始第90天的预测
# (608, 53) (608,) (1, 53)
# Training until validation scores don't improve for 200 rounds
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# [200]	valid_0's l2: 1.11442e+08
# Early stopping, best iteration is:
# [84]	valid_0's l2: 1.1049e+08
# cv_score is: [110490379.76890402]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.77988e+07
# Early stopping, best iteration is:
# [196]	valid_0's l2: 6.77065e+07
# cv_score is: [110490379.76890402, 67706514.16381861]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.43086e+08
# Early stopping, best iteration is:
# [32]	valid_0's l2: 1.26983e+08
# cv_score is: [110490379.76890402, 67706514.16381861, 126982931.40257658]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.82051e+07
# Early stopping, best iteration is:
# [88]	valid_0's l2: 6.60499e+07
# cv_score is: [110490379.76890402, 67706514.16381861, 126982931.40257658, 66049914.252642386]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.18531e+08
# [400]	valid_0's l2: 1.18204e+08
# Early stopping, best iteration is:
# [224]	valid_0's l2: 1.17922e+08
# cv_score is: [110490379.76890402, 67706514.16381861, 126982931.40257658, 66049914.252642386, 117921882.36059424]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 3.25337e+07
# Early stopping, best iteration is:
# [57]	valid_0's l2: 2.89383e+07
# cv_score is: [110490379.76890402, 67706514.16381861, 126982931.40257658, 66049914.252642386, 117921882.36059424, 28938297.92187905]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.00308e+08
# Early stopping, best iteration is:
# [32]	valid_0's l2: 8.83558e+07
# cv_score is: [110490379.76890402, 67706514.16381861, 126982931.40257658, 66049914.252642386, 117921882.36059424, 28938297.92187905, 88355786.63356616]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 8.56255e+07
# Early stopping, best iteration is:
# [50]	valid_0's l2: 7.90742e+07
# cv_score is: [110490379.76890402, 67706514.16381861, 126982931.40257658, 66049914.252642386, 117921882.36059424, 28938297.92187905, 88355786.63356616, 79074173.51891854]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 1.44218e+08
# [400]	valid_0's l2: 1.42352e+08
# Early stopping, best iteration is:
# [371]	valid_0's l2: 1.4211e+08
# cv_score is: [110490379.76890402, 67706514.16381861, 126982931.40257658, 66049914.252642386, 117921882.36059424, 28938297.92187905, 88355786.63356616, 79074173.51891854, 142110380.58530563]
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's l2: 6.63609e+07
# Early stopping, best iteration is:
# [182]	valid_0's l2: 6.60748e+07
# cv_score is: [110490379.76890402, 67706514.16381861, 126982931.40257658, 66049914.252642386, 117921882.36059424, 28938297.92187905, 88355786.63356616, 79074173.51891854, 142110380.58530563, 66074769.48159366]
# --------------------------------------------------
# loacl valid scores is 1743.5992443718137
# val_mean: 89370503.00897989
# val_std: 32821311.44370646
# 第90天的预测值为[201353.44816144]
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1 = df[1035:1035+90][['date','B']]
df1.index=df1.date

with pd.plotting.plot_params.use('x_compat', True):
    df1['B'].plot(y=df1['B'],figsize=(15,8))

# %%
df1 = df[1035:][['date','B']]
df1
# Out:
#           date              B
# 0   2020-11-01  237347.675952
# 1   2020-11-02  243637.457991
# 2   2020-11-03  239925.276066
# 3   2020-11-04  235169.958565
# 4   2020-11-05  237643.335812
# ..         ...            ...
# 146 2021-03-27       0.000000
# 147 2021-03-28       0.000000
# 148 2021-03-29       0.000000
# 149 2021-03-30       0.000000
# 150 2021-03-31       0.000000
#
# [151 rows x 2 columns]

# %%
df1.to_csv('./data/daybyday_new_group_features_B.csv',index=False)

# %%
df2=pd.read_csv('./data/daybyday_new_group_features_A.csv')
df2
# Out:
#            date              A
# 0    2020-11-01  270338.039043
# 1    2020-11-02  269113.663029
# 2    2020-11-03  269197.652956
# 3    2020-11-04  267300.493228
# 4    2020-11-05  266541.020046
# ..          ...            ...
# 146  2021-03-27       0.000000
# 147  2021-03-28       0.000000
# 148  2021-03-29       0.000000
# 149  2021-03-30       0.000000
# 150  2021-03-31       0.000000
#
# [151 rows x 2 columns]

# %%
test_v11 = pd.read_csv('../data/test.csv')
test_v11
# Out:
#              日期  A厂  B厂
# 0    2020/11/01   0   0
# 1    2020/11/02   0   0
# 2    2020/11/03   0   0
# 3    2020/11/04   0   0
# 4    2020/11/05   0   0
# ..          ...  ..  ..
# 146  2021/03/27   0   0
# 147  2021/03/28   0   0
# 148  2021/03/29   0   0
# 149  2021/03/30   0   0
# 150  2021/03/31   0   0
#
# [151 rows x 3 columns]

# %%
test_v11['A厂']=df2.A
test_v11['B厂']=df1.B
test_v11
# Out:
#              日期             A厂             B厂
# 0    2020/11/01  270338.039043  237347.675952
# 1    2020/11/02  269113.663029  243637.457991
# 2    2020/11/03  269197.652956  239925.276066
# 3    2020/11/04  267300.493228  235169.958565
# 4    2020/11/05  266541.020046  237643.335812
# ..          ...            ...            ...
# 146  2021/03/27       0.000000       0.000000
# 147  2021/03/28       0.000000       0.000000
# 148  2021/03/29       0.000000       0.000000
# 149  2021/03/30       0.000000       0.000000
# 150  2021/03/31       0.000000       0.000000
#
# [151 rows x 3 columns]

# %%
test_v11.to_csv('./data/test_new1.csv',index=False)

# %%
df3 = pd.read_csv('./data/test_new1.csv')
df3.columns=['date','A','B']
df3
# Out:
#           date            A            B
# 0    2020/11/1  270338.0390  237347.6760
# 1    2020/11/2  269113.6630  243637.4580
# 2    2020/11/3  269197.6530  239925.2761
# 3    2020/11/4  267300.4932  235169.9586
# 4    2020/11/5  266541.0200  237643.3358
# ..         ...          ...          ...
# 146  2021/3/27  296200.0000  254474.0000
# 147  2021/3/28  298541.0000  255556.0000
# 148  2021/3/29  304362.0000  256910.0000
# 149  2021/3/30  303664.0000  256423.0000
# 150  2021/3/31  307821.0000  256011.0000
#
# [151 rows x 3 columns]

# %% [markdown]
# # 规则：(不如不做0.9192)
# A厂在stepbystep的1月1日到29日直接加10000，
# 2月12日到2月16在原有基础上-10000，1月30到2月11日保持不变
#
# B厂在stepbystep的1月1日到29日直接加20000，1月30到2月6日+30000，2月7日到11日不变，
# 2月12日到2月16日-20000

# %%
test_v11 = pd.read_csv('../data/test.csv')
test_v11
# Out:
#              日期  A厂  B厂
# 0    2020/11/01   0   0
# 1    2020/11/02   0   0
# 2    2020/11/03   0   0
# 3    2020/11/04   0   0
# 4    2020/11/05   0   0
# ..          ...  ..  ..
# 146  2021/03/27   0   0
# 147  2021/03/28   0   0
# 148  2021/03/29   0   0
# 2    2020/11/3  265203.0  241281
# 3    2020/11/4  263442.0  242709
# 4    2020/11/5  261568.0  242040
# ..         ...       ...     ...
# 146  2021/3/27  264465.0  212062
# 147  2021/3/28  266555.0  212964
# 148  2021/3/29  271752.0  214092
# 149  2021/3/30  271129.0  213686
# 150  2021/3/31  274841.0  213343
#
# [151 rows x 3 columns]

# %%
test_v11 = pd.read_csv('./data/test.csv')
test_v11
# Out:
#              日期  A厂  B厂
# 0    2020/11/01   0   0
# 1    2020/11/02   0   0
# 2    2020/11/03   0   0
# 3    2020/11/04   0   0
# 4    2020/11/05   0   0
# ..          ...  ..  ..
# 146  2021/03/27   0   0
# 147  2021/03/28   0   0
# 148  2021/03/29   0   0
# 149  2021/03/30   0   0
# 150  2021/03/31   0   0
#
# [151 rows x 3 columns]

# %%
test_v11['A厂'] = test_v111['A厂'].astype(int)
test_v11['B厂'] = test_v111['B厂'].astype(int)
test_v11
# Out:
#              日期      A厂      B厂
# 0    2020/11/01  272374  234141
# 1    2020/11/02  268795  239837
# 2    2020/11/03  265203  241281
# 3    2020/11/04  263442  242709
# 4    2020/11/05  261568  242040
# ..          ...     ...     ...
# 146  2021/03/27  264465  212062
# 147  2021/03/28  266555  212964
# 148  2021/03/29  271752  214092
# 149  2021/03/30  271129  213686
# 150  2021/03/31  274841  213343
#
# [151 rows x 3 columns]

# %%
test_v11.to_csv('./data/lgb_stepbystep_without_1_2_2020_mult15.csv',index=False,encoding='utf-8')

# %%
test_v111 = pd.read_csv('./data/lgb_stepbystep_without_1_2_2020_1.csv')
test_v111.columns=['日期','A厂','B厂']
test_v111
# Out:
#             日期         A厂        B厂
# 0    2020/11/1  272374.00  234141.0
# 1    2020/11/2  268795.00  239837.0
# 2    2020/11/3  265203.00  241281.0
# 3    2020/11/4  263442.00  242709.0
# 4    2020/11/5  261568.00  242040.0
# ..         ...        ...       ...
# 146  2021/3/27  277688.25  233268.2
# 147  2021/3/28  279882.75  234260.4
# 148  2021/3/29  285339.60  235501.2
# 149  2021/3/30  284685.45  235054.6
# 150  2021/3/31  288583.05  234677.3
#
# [151 rows x 3 columns]

# %%
test_v11 = pd.read_csv('./data/test.csv')
test_v11['A厂'] = test_v111['A厂'].astype(int)
test_v11['B厂'] = test_v111['B厂'].astype(int)
test_v11
# Out:
#              日期      A厂      B厂
# 0    2020/11/01  272374  234141
# 1    2020/11/02  268795  239837
# 2    2020/11/03  265203  241281
# 3    2020/11/04  263442  242709
# 4    2020/11/05  261568  242040
# ..          ...     ...     ...
# 146  2021/03/27  277688  233268
# 147  2021/03/28  279882  234260
# 148  2021/03/29  285339  235501
# 149  2021/03/30  284685  235054
# 150  2021/03/31  288583  234677
#
# [151 rows x 3 columns]

# %%
test_v11.to_csv('./data/lgb_stepbystep_without_1_2_2020_multguonian.csv',index=False,encoding='utf-8')

# %% [markdown]
# 过年，A*1.5，B*1.1   从初六开始

# %% [markdown]
# 过年，A1.1，B1.15 从初六开始 分数最高
